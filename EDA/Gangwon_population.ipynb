# %% [markdown]
# <a href="https://colab.research.google.com/github/minit88/Sk_MA_-Competition/blob/main/EDA/Gangwon_population.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data=pd.read_csv('/content/Gangwon_population.csv',encoding='cp949')
print(data.head())
# Out:
#      시점     세대수      인구수    남자인구    여자인구      한국인인구     한국인남자     한국인여자  \
# 0  1961  296732  1585869  791267  794602        NaN       NaN       NaN
# 1  1962  295754  1593037  808319  784718  1593037.0       NaN       NaN
# 2  1963  305792  1678126  852652  825474  1678126.0  852652.0  825474.0
# 3  1964  308605  1722005  878558  843447  1722005.0  878558.0  843447.0
# 4  1965  312688  1771035  902167  868868  1771035.0  902167.0  868868.0
#
#    외국인인구  외국인남자  외국인여자  인구증가율  세대당인구  65세이상고령자   인구밀도        면적
# 0    NaN    NaN    NaN    NaN    5.3       NaN   92.3  17184.81
# 1    NaN    NaN    NaN    NaN    5.4       NaN   92.7  17184.81
# 2    0.0    NaN    NaN    5.3    5.5       NaN  101.0  16618.20
# 3    0.0    NaN    NaN    2.6    5.6       NaN  103.6  16618.20
# 4    0.0    0.0    0.0    2.8    5.7       0.0  106.0  16712.20

# %%
a1=data.groupby('시점')[['인구수','인구증가율','65세이상고령자','인구밀도']]
a1.head()
# Out:
#         인구수  인구증가율  65세이상고령자   인구밀도
# 0   1585869    NaN       NaN   92.3
# 1   1593037    NaN       NaN   92.7
# 2   1678126    5.3       NaN  101.0
# 3   1722005    2.6       NaN  103.6
# 4   1771035    2.8       0.0  106.0
# 5   1832383    3.5       0.0  109.6
# 6   1825018   -0.4       0.0  109.2
# 7   1823612   -0.1       0.0  109.1
# 8   1810527   -0.7       0.0  108.3
# 9   1866928    3.1       0.0  111.7
# 10  1851866   -0.8       0.0  110.8
# 11  1863419    0.6       0.0  111.5
# 12  1852456   -0.6       0.0  110.4
# 13  1865738    0.7       0.0  110.9
# 14  1862107   -0.2       0.0  110.7
# 15  1842363   -1.0       0.0  109.7
# 16  1847177    0.3       0.0  109.4
# 17  1852755    0.3       0.0  109.7
# 18  1844559   -0.4       0.0  109.2
# 19  1790954   -2.9       0.0  106.0
# 20  1804853    0.8       0.0  106.8
# 21  1809871    0.3       0.0  107.1
# 22  1824324    0.8       0.0  108.0
# 23  1816365   -0.4       0.0  107.5
# 24  1724809   -5.0       0.0  102.1
# ...

# %% [markdown]
# # **연도별 인구밀도**

# %%
plt.plot(data['시점'],data['인구수'])
plt.grid(True)

# %% [markdown]
# # **연도별 인구증가율**

# %%
plt.plot(data['시점'],data['인구증가율'])
plt.grid(True)

# %% [markdown]
# # **연도별 65세이상고령자**

# %%
plt.plot(data['시점'],data['65세이상고령자'])
plt.grid(True)

# %% [markdown]
# # **연도별 인구밀도**

# %%
plt.plot(data['시점'],data['인구밀도'])
plt.grid(True)
